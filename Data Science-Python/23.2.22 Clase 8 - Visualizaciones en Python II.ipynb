# %% [markdown]
# # 23.2.22 clase 8 - Visualizaciones en Python II

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ##### Ejemplos de subgráficos
# Primero traemos el data set

# %%
df_lluvias = pd.read_csv('pune_1965_to_2002.csv')
df_lluvias.head()
# Out:
#    Year    Jan    Feb    Mar     Apr     May      Jun      Jul      Aug  \
# 0  1965  0.029  0.069  0.000  21.667  17.859  102.111  606.071  402.521
# 1  1966  0.905  0.000  0.000   2.981  63.008   94.088  481.942   59.386
# 2  1967  0.248  3.390  1.320  13.482  11.116  251.314  780.006  181.069
# 3  1968  0.318  3.035  1.704  23.307   7.441  179.872  379.354  171.979
# 4  1969  0.248  2.524  0.334   4.569   6.213  393.682  678.354  397.335
#
#        Sep     Oct     Nov     Dec
# 0   69.511   5.249  16.232  22.075
# 1  150.624   1.308  41.214   4.132
# 2  183.757  50.404   8.393  37.685
# 3  219.884  73.997  23.326   2.020
# 4  205.413  24.014  24.385   1.951

# %%
df_lluvias.index = df_lluvias['Year']
df_lluvias = df_lluvias.drop(['Year'], axis='columns')
df_lluvias
# Out:
#         Jan    Feb    Mar     Apr     May      Jun      Jul      Aug      Sep  \
# Year
# 1965  0.029  0.069  0.000  21.667  17.859  102.111  606.071  402.521   69.511
# 1966  0.905  0.000  0.000   2.981  63.008   94.088  481.942   59.386  150.624
# 1967  0.248  3.390  1.320  13.482  11.116  251.314  780.006  181.069  183.757
# 1968  0.318  3.035  1.704  23.307   7.441  179.872  379.354  171.979  219.884
# 1969  0.248  2.524  0.334   4.569   6.213  393.682  678.354  397.335  205.413
# 1970  0.070  0.000  0.001  16.218  68.036  300.546  330.502  283.476  158.640
# 1971  0.000  0.000  0.000   0.812  57.691  297.187  122.195  372.693  286.056
# 1972  0.000  0.029  0.000   5.982  19.101  132.413  338.484   68.741  120.415
# 1973  0.000  2.969  0.234   3.925  14.978  304.484  696.024  256.932  183.206
# 1974  0.000  0.000  6.427  16.864  51.209  148.697  405.359  319.651  288.533
# 1975  0.333  0.585  0.000   0.061  30.651  359.369  474.143  404.372  400.001
# ...

# %%
#Metemos un grafico que compare 3 series
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 5), sharex=True, sharey=True)
#eje x ponemos los años
x = df_lluvias.index
#eje y ponemos las lluvias para cada mes a comparar
ax[0].plot(df_lluvias.index, df_lluvias['Jan'], label='Precipitaciones de enero')
ax[1].plot(df_lluvias.index, df_lluvias['Feb'], label='Precipitaciones de febrero', color='C1')
ax[2].plot(df_lluvias.index, df_lluvias['Mar'], label='Precipitaciones de marzo', color='C2')
#añadimos texto
ax[0].set_title('Precipitaciones de los primeros tres meses del año') 
ax[2].set_xlabel('Año')  
ax[1].set_ylabel('Precipitación (mm.)')
#agregamos las leyendas
ax[0].legend()  
ax[1].legend()
ax[2].legend()

# %% [markdown]
# #### Se puede personalizar Matplotlib

# %%
#Esto es todo lo disponible para personalizar
mpl.rcParams.keys()
# Out:
# KeysView(RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
#           'axes.grid': False,
# ...

# %% [markdown]
# #### Por ejemplo

# %%
mpl.rcParams['axes.titleweight'] = 'bold' 
mpl.rcParams['axes.titlelocation'] = 'left' 
mpl.rcParams['axes.titlecolor'] = 'firebrick' 
mpl.rcParams['axes.labelcolor'] = 'blue' 
mpl.rcParams['axes.labelsize'] = '10' 
mpl.rcParams['axes.labelweight'] = 'light' 
mpl.rcParams['axes.linewidth'] = '1' 
mpl.rcParams['grid.color'] = 'black' 
mpl.rcParams['grid.linestyle'] = '-.' 
mpl.rcParams['grid.linewidth'] = '2'

# %% [markdown]
# #### Dandole algunos valores a estos parámetros

# %%
fig, ax = plt.subplots(figsize=(7, 4))  
ax.scatter(df_lluvias['Aug'], df_lluvias['Sep'], c=df_lluvias.index)
ax.set_title('(Título rojo en negrita)')
ax.set_xlabel('(Etiqueta eje horiz.)')
ax.set_ylabel('(Etiqueta eje vert.)')
# Out:
# Text(0, 0.5, '(Etiqueta eje vert.)')

# %% [markdown]
# #### Otra forma es
# No me funciona, tengo que revisarlo

# %%
#plt.rc('axes', titlelocation='left', titlecolor='firebrick', ...)
#plt.rc('grid', color='black', linestyle='-.', ...)

# %% [markdown]
# ##### Reestablecer

# %%
mpl.rcParams.update(mpl.rcParamsDefault)

# %% [markdown]
# ## Seaborn

# %%
sns.set()

# %% [markdown]
# #### Trae datasets de prueba

# %%
df_ejercicio = sns.load_dataset('exercise')
df_ejercicio = df_ejercicio.drop('Unnamed: 0', axis='columns')
df_ejercicio.head()
# Out:
#    id     diet  pulse    time  kind
# 0   1  low fat     85   1 min  rest
# 1   1  low fat     85  15 min  rest
# 2   1  low fat     88  30 min  rest
# 3   2  low fat     90   1 min  rest
# 4   2  low fat     92  15 min  rest

# %% [markdown]
# #### Traigo los que entrenaron sólo 30 minutos

# %%
df_30_min = df_ejercicio[df_ejercicio['time'] == '30 min']
df_30_min.head()
# Out:
#     id     diet  pulse    time  kind
# 2    1  low fat     88  30 min  rest
# 5    2  low fat     93  30 min  rest
# 8    3  low fat     94  30 min  rest
# 11   4  low fat     83  30 min  rest
# 14   5  low fat     91  30 min  rest

# %% [markdown]
# #### Graficamos las distribuciones

# %%
plt.figure()
ax = sns.displot(data=df_30_min, x='pulse', kind='kde', hue='kind', fill=True)
ax.set(xlabel='Frecuencia Cardíaca', ylabel='Densidad', title='Distribución  de las pulsaciones')

# %%
plt.figure()
ax = sns.displot(data=df_30_min, x='pulse', kind='hist', hue='kind', fill=True)
ax.set(xlabel='Frecuencia Cardíaca', ylabel='Densidad', title='Distribución  de las pulsaciones')

# %%
plt.figure()
ax = sns.displot(data=df_30_min, x='pulse', kind='kde', hue='diet', fill=True)
ax.set(xlabel='Frecuencia Cardíaca', ylabel='Densidad', title='Distribución  de las pulsaciones')

# %% [markdown]
# #### Visualizar los datos en base a dos variables distintas
# sns.catplot <br>
# kind='violin'<br>
# Visualizamos pulsaciones en base a actividad y tipo de dieta

# %%
ax = sns.catplot(data=df_ejercicio, kind='violin', x='time', y='pulse', hue='diet', split=True)
ax.set(xlabel='Duración de ejercicio', ylabel='Frecuencia cardíaca', title='Categorización de la distribución de pulsaciones')

# %% [markdown]
# #### Para visualizar en base a la actividad le cambiamos el valor de x

# %%
ax = sns.catplot(data=df_ejercicio, kind='violin', x='kind', y='pulse', hue='diet', split=True)
ax.set(xlabel='Tipo de ejercicio', ylabel='Frecuencia cardíaca', title='Categorización de la distribución de pulsaciones')

# %% [markdown]
# ##### Entregable
# Visualización en Python <br>
# Estadísticas descriptivas básicas

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# #### Cargo dataset

# %%
df_HR = pd.read_csv('HRDataset_v14.csv')
df_HR.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %% [markdown]
# #### 1)Descripción general; estadísticas descriptivas básicas

# %%
df_HR.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %% [markdown]
# #### Checkeo los nulos

# %%
df_HR.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %% [markdown]
# #### 2)Histograma de salarios

# %% [markdown]
# #### Dada la columna de los salarios del personal

# %%
df_HR['Salary']
# Out:
# 0       62506
# 1      104437
# 2       64955
# 3       64991
# 4       50825
#         ...
# 306     65893
# 307     48513
# 308    220450
# 309     89292
# 310     45046
# Name: Salary, Length: 311, dtype: int64

# %% [markdown]
# #### Se grafica el histograma

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.hist(df_HR['Salary'].values.flatten(), bins=10)#Grafico de histograma
ax.set_title('Histograma de salarios')
ax.set_xlabel('Intervalos de salarios [$]')
ax.set_ylabel('Frecuencia absoluta')
# Out:
# Text(0, 0.5, 'Frecuencia absoluta')

# %% [markdown]
# #### 3)Grafico violín con los salarios discriminados por género

# %%
plt.figure()
ax = sns.catplot(data=df_HR, kind='violin', y='Salary', hue='GenderID', split=True)
ax.set(xlabel='Duración de ejercicio', ylabel='Frecuencia cardíaca', title='Categorización de la distribución de pulsaciones')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [37], in <module>
#       1 plt.figure()
# ----> 2 ax = sns.catplot(data=df_HR, kind='violin', y='Salary', hue='GenderID', split=True)
#       3 ax.set(xlabel='Duración de ejercicio', ylabel='Frecuencia cardíaca', title='Categorización de la distribución de pulsaciones')
#
# File ~\miniconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %% [markdown]
# #### 4)Contrataciones por fecha

# %%
df_HR['DateofHire']
# Out:
# 0       7/5/2011
# 1      3/30/2015
# 2       7/5/2011
# 3       1/7/2008
# 4      7/11/2011
#          ...
# 306     7/7/2014
# 307     9/2/2008
# 308    4/10/2010
# 309    3/30/2015
# 310    9/29/2014
# Name: DateofHire, Length: 311, dtype: object

# %% [markdown]
# #### Convierto a formato fecha

# %%
df_HR['DateofHire'] = pd.to_datetime(df_HR['DateofHire'])
df_HR['DateofHire']
# Out:
# 0     2011-07-05
# 1     2015-03-30
# 2     2011-07-05
# 3     2008-01-07
# 4     2011-07-11
#          ...
# 306   2014-07-07
# 307   2008-09-02
# 308   2010-04-10
# 309   2015-03-30
# 310   2014-09-29
# Name: DateofHire, Length: 311, dtype: datetime64[ns]

# %% [markdown]
# #### Armo columna año

# %%
df_HR['Year'] = df_HR['DateofHire'].dt.year 
df_HR['Year']
# Out:
# 0      2011
# 1      2015
# 2      2011
# 3      2008
# 4      2011
#        ...
# 306    2014
# 307    2008
# 308    2010
# 309    2015
# 310    2014
# Name: Year, Length: 311, dtype: int64

# %% [markdown]
# #### Defino el eje y para el gráfico

# %%
y = df_HR.groupby('Year')['EmpID'].count()
y
# Out:
# Year
# 2006     1
# 2007     2
# 2008     3
# 2009     7
# 2010     9
# 2011    83
# 2012    45
# 2013    44
# 2014    60
# 2015    36
# 2016    14
# 2017     6
# 2018     1
# Name: EmpID, dtype: int64

# %% [markdown]
# #### Grafico

# %%
fig, ax = plt.subplots(figsize=(12,4))
ax.plot(y,label='Cantidad contrataciones')
#No defino eje x, pues en la tabla no los tengo acumulados por año

# %%
ax.set_xlabel('Año')
ax.set_ylabel('Cantidad contrataciones')
ax.set_title('Cantidad contrataciones por año')
ax.legend(loc='upper right')#cambio localización de la etiqueta

fig #Llamo al gráfico
