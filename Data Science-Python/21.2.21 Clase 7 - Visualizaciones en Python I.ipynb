# %% [markdown]
# # Clase 7 - Visualizaciones en Python I

# %% [markdown]
# #### Importo las libreiras

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# #### Si quiero cambiar el estilo de mpl

# %%
mpl.style.use('bmh')

# %% [markdown]
# #### Ejemplo aplicación simple

# %% [markdown]
# #### Interfaz orientada a objetos; esta utilizamos a lo largo del curso

# %%
fig, ax = plt.subplots()
ax.plot([1,3],[2,4])

# %% [markdown]
# #### Otra forma; interfaz orientada a estados

# %%
plt.plot([1,3], [2,4])

# %% [markdown]
# #### Parece simple al principio, luego se complica

# %% [markdown]
# #### Siempre incluir información de lo que se muestra; nombre de ejes, titulo, leyenda

# %% [markdown]
# #### Importo los datasets

# %%
df_lluvias = pd.read_csv('pune_1965_to_2002.csv')
df_lluvias.head()
# Out:
#    Year    Jan    Feb    Mar     Apr     May      Jun      Jul      Aug  \
# 0  1965  0.029  0.069  0.000  21.667  17.859  102.111  606.071  402.521
# 1  1966  0.905  0.000  0.000   2.981  63.008   94.088  481.942   59.386
# 2  1967  0.248  3.390  1.320  13.482  11.116  251.314  780.006  181.069
# 3  1968  0.318  3.035  1.704  23.307   7.441  179.872  379.354  171.979
# 4  1969  0.248  2.524  0.334   4.569   6.213  393.682  678.354  397.335
#
#        Sep     Oct     Nov     Dec
# 0   69.511   5.249  16.232  22.075
# 1  150.624   1.308  41.214   4.132
# 2  183.757  50.404   8.393  37.685
# 3  219.884  73.997  23.326   2.020
# 4  205.413  24.014  24.385   1.951

# %% [markdown]
# #### Ponemos a Year como indice, y eliminamos el anterior

# %%
df_lluvias.index = df_lluvias['Year']
df_lluvias
# Out:
#       Year    Jan    Feb    Mar     Apr     May      Jun      Jul      Aug  \
# Year
# 1965  1965  0.029  0.069  0.000  21.667  17.859  102.111  606.071  402.521
# 1966  1966  0.905  0.000  0.000   2.981  63.008   94.088  481.942   59.386
# 1967  1967  0.248  3.390  1.320  13.482  11.116  251.314  780.006  181.069
# 1968  1968  0.318  3.035  1.704  23.307   7.441  179.872  379.354  171.979
# 1969  1969  0.248  2.524  0.334   4.569   6.213  393.682  678.354  397.335
# 1970  1970  0.070  0.000  0.001  16.218  68.036  300.546  330.502  283.476
# 1971  1971  0.000  0.000  0.000   0.812  57.691  297.187  122.195  372.693
# 1972  1972  0.000  0.029  0.000   5.982  19.101  132.413  338.484   68.741
# 1973  1973  0.000  2.969  0.234   3.925  14.978  304.484  696.024  256.932
# 1974  1974  0.000  0.000  6.427  16.864  51.209  148.697  405.359  319.651
# 1975  1975  0.333  0.585  0.000   0.061  30.651  359.369  474.143  404.372
# ...

# %%
df_lluvias = df_lluvias.drop(['Year'], axis='columns')
df_lluvias
# Out:
#         Jan    Feb    Mar     Apr     May      Jun      Jul      Aug      Sep  \
# Year
# 1965  0.029  0.069  0.000  21.667  17.859  102.111  606.071  402.521   69.511
# 1966  0.905  0.000  0.000   2.981  63.008   94.088  481.942   59.386  150.624
# 1967  0.248  3.390  1.320  13.482  11.116  251.314  780.006  181.069  183.757
# 1968  0.318  3.035  1.704  23.307   7.441  179.872  379.354  171.979  219.884
# 1969  0.248  2.524  0.334   4.569   6.213  393.682  678.354  397.335  205.413
# 1970  0.070  0.000  0.001  16.218  68.036  300.546  330.502  283.476  158.640
# 1971  0.000  0.000  0.000   0.812  57.691  297.187  122.195  372.693  286.056
# 1972  0.000  0.029  0.000   5.982  19.101  132.413  338.484   68.741  120.415
# 1973  0.000  2.969  0.234   3.925  14.978  304.484  696.024  256.932  183.206
# 1974  0.000  0.000  6.427  16.864  51.209  148.697  405.359  319.651  288.533
# 1975  0.333  0.585  0.000   0.061  30.651  359.369  474.143  404.372  400.001
# ...

# %% [markdown]
# #### Graficamos

# %%
x = df_lluvias.index
x
# Out:
# Int64Index([1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975,
#             1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#             1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#             1998, 1999, 2000, 2001, 2002],
#            dtype='int64', name='Year')

# %%
y = df_lluvias.sum(axis='columns')
y
# Out:
# Year
# 1965    1263.394
# 1966     899.588
# 1967    1522.184
# 1968    1086.237
# 1969    1739.022
# 1970    1273.507
# 1971    1176.612
# 1972     710.475
# 1973    1570.073
# 1974    1425.876
# 1975    1777.838
# 1976    1941.167
# 1977    1202.154
# 1978    1168.583
# 1979    1769.187
# 1980    1268.185
# 1981    1562.761
# 1982     943.087
# 1983    1616.948
# 1984    1538.961
# 1985    1214.852
# 1986    1267.969
# 1987    1197.999
# 1988    1822.649
# 1989    1400.024
# 1990    1766.294
# 1991    1497.256
# 1992    1323.883
# 1993    1210.252
# 1994    1987.689
# 1995    1209.068
# 1996    1631.331
# 1997    1844.840
# 1998    1603.243
# 1999    1235.683
# 2000    1094.062
# 2001    1045.825
# 2002    1024.881
# dtype: float64

# %% [markdown]
# #### Definimos los objetos fig y ax

# %%
fig, ax = plt.subplots(figsize=(12,4))
ax.plot(x,y,label='Precipitaciones acumuladas')

# %% [markdown]
# #### Añadimos etiqetas a ejes

# %%
ax.set_xlabel('Año')
ax.set_ylabel('Precipitación acumulada (mm.)')
ax.set_title('Precipitaciones acumuladas según el año')
ax.legend(loc='lower right')#cambio localización de la etiqueta
fig #Llamo al gráfico

# %% [markdown]
# ##### Recortar bordes vacios del gráfico

# %%
ax.set_xlim(df_lluvias.index[0],df_lluvias.index[-1])
fig

# %% [markdown]
# ##### Guardar gráficos

# %%
#Puede ser formato jpeg, jpg, png, pdf, svg)
fig.savefig("precipitaciones_del_1965_al_2002.pdf")

# %% [markdown]
# ##### Armamos otro ejemplo

# %% [markdown]
# ##### si no se agregan las etiquetas del eje x, se pone directamente 1,2,3,..,n

# %%
fig, ax = plt.subplots()
ax.plot([0,1,2,3,4,5,6],[1,5,2,4,8,9,2])

# %% [markdown]
# ##### Sería lo mismo que

# %%
fig, ax = plt.subplots()
ax.plot([1,5,2,4,8,9,2])

# %% [markdown]
# #### Grafico de nubes de puntos,
# #ax.scatter

# %%
fig, ax = plt.subplots()
ax.scatter(x,y, alpha=0.5)#Grafico puntos
ax.set_title('Lluvia vs año')
ax.set_xlabel('Año')
ax.set_ylabel('Cantidad lluvia .mm')
# Out:
# Text(0, 0.5, 'Cantidad lluvia .mm')

# %% [markdown]
# ####  Otro grafico
# Ahora vemos la corelación entre Agosto y Septiembre

# %%
fig, ax = plt.subplots()  
mapeo_colores = ax.scatter(df_lluvias['Aug'], df_lluvias['Sep'], c=df_lluvias.index)
fig.colorbar(mapeo_colores)#Grafico puntos
ax.set_title('Precipitaciones Agosto-Septiembre')
ax.set_xlabel('Precipitaciones en Agosto (mm.)')
ax.set_ylabel('Precipitaciones en Septiembre (mm.)')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13408\293828453.py:3: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   fig.colorbar(mapeo_colores)#Grafico puntos
# Text(0, 0.5, 'Precipitaciones en Septiembre (mm.)')

# %% [markdown]
# #### Grafico de barras

# %%
precipitaciones_acumuladas = df_lluvias.sum()
precipitaciones_acumuladas
# Out:
# Jan       11.186
# Feb       41.843
# Mar       63.733
# Apr      470.487
# May      952.272
# Jun    12809.663
# Jul    16340.395
# Aug    10529.357
# Sep     7642.245
# Oct     2783.320
# Nov      958.492
# Dec      230.646
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8,4))
precipitaciones_acumuladas = df_lluvias.sum()
ax.bar(df_lluvias.columns, precipitaciones_acumuladas)#Grafico de barras
ax.set_title('Precipitaciones acumuladas desde 1965 a 2002, según el mes')
ax.set_ylabel('Precipitación total (mm.)')
ax.set_xlabel('Mes')
# Out:
# Text(0.5, 0, 'Mes')

# %% [markdown]
# #### Aplicamos histograma

# %%
df_lluvias.values.flatten()
# Out:
# array([2.90000e-02, 6.90000e-02, 0.00000e+00, 2.16670e+01, 1.78590e+01,
#        1.02111e+02, 6.06071e+02, 4.02521e+02, 6.95110e+01, 5.24900e+00,
#        1.62320e+01, 2.20750e+01, 9.05000e-01, 0.00000e+00, 0.00000e+00,
#        2.98100e+00, 6.30080e+01, 9.40880e+01, 4.81942e+02, 5.93860e+01,
#        1.50624e+02, 1.30800e+00, 4.12140e+01, 4.13200e+00, 2.48000e-01,
#        3.39000e+00, 1.32000e+00, 1.34820e+01, 1.11160e+01, 2.51314e+02,
#        7.80006e+02, 1.81069e+02, 1.83757e+02, 5.04040e+01, 8.39300e+00,
#        3.76850e+01, 3.18000e-01, 3.03500e+00, 1.70400e+00, 2.33070e+01,
#        7.44100e+00, 1.79872e+02, 3.79354e+02, 1.71979e+02, 2.19884e+02,
#        7.39970e+01, 2.33260e+01, 2.02000e+00, 2.48000e-01, 2.52400e+00,
#        3.34000e-01, 4.56900e+00, 6.21300e+00, 3.93682e+02, 6.78354e+02,
#        3.97335e+02, 2.05413e+02, 2.40140e+01, 2.43850e+01, 1.95100e+00,
#        7.00000e-02, 0.00000e+00, 1.00000e-03, 1.62180e+01, 6.80360e+01,
# ...

# %% [markdown]
# #### Ahora graficamos

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.hist(df_lluvias.values.flatten(), bins=10)#Grafico de histograma
ax.set_title('Histograma de precipitaciones')
ax.set_xlabel('Intervalos de precipitaciones (mm.)')
ax.set_ylabel('Frecuencia absoluta')
# Out:
# Text(0, 0.5, 'Frecuencia absoluta')

# %% [markdown]
# #### Multiples elementos

# %%
fig, ax = plt.subplots(figsize=(12, 3))  
ax.plot(df_lluvias.index, df_lluvias['Jan'], label='Precipitaciones de enero')
ax.plot(df_lluvias.index, df_lluvias['Feb'], label='Precipitaciones de febrero', color='C1')

# %% [markdown]
# #### Calculamos el máximo de cada serie

# %%
maximo_enero = df_lluvias['Jan'].max()
maximo_enero
# Out:
# 3.013

# %%
maximo_febrero =  df_lluvias['Feb'].max()
maximo_febrero
# Out:
# 8.41

# %% [markdown]
# #### Dibujamos el máximo de cada serie

# %%
fig, ax = plt.subplots(figsize=(12, 3))  
ax.plot(df_lluvias.index, df_lluvias['Jan'], label='Precipitaciones de enero')
ax.plot(df_lluvias.index, df_lluvias['Feb'], label='Precipitaciones de febrero', color='C1')
#Agregamos lineas de máximos
ax.axhline(maximo_enero, linestyle='--', alpha=0.5,    linewidth=3, label='Máxima de enero')
ax.axhline(maximo_febrero, color='C1', linestyle=':', alpha=0.5, linewidth=3, label='Máxima de febrero')

# %%
fig, ax = plt.subplots(figsize=(12, 3))  
ax.plot(df_lluvias.index, df_lluvias['Jan'], label='Precipitaciones de enero')
ax.plot(df_lluvias.index, df_lluvias['Feb'], label='Precipitaciones de febrero', color='C1')
#Agregamos lineas de máximos
ax.axhline(maximo_enero, linestyle='--', alpha=0.5,    linewidth=3, label='Máxima de enero')
ax.axhline(maximo_febrero, color='C1', linestyle=':', alpha=0.5, linewidth=3, label='Máxima de febrero')
#Agregamos labels
ax.set_xlabel('Año')  
ax.set_ylabel('Precipitación (mm.)') 
ax.set_title('Precipitaciones de enero y febrero') 	
#Eliminamos espacios vacios
ax.set_xlim(df_lluvias.index[0], df_lluvias.index[-1])
#Mostramos los nombres de las líneas dibujadas
ax.legend()

# %%
#Lo guardamos si queremos
fig.savefig("precipitaciones_del_1965_al_2002(1).png")
#El .png pierde mucha definición, es mejor pdf
